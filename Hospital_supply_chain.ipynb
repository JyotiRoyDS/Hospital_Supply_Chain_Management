# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as py
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("hospital_supply_chain.csv")

# %%
df.head()
# Out:
#                 Item Name     Supplier  Quantity  Cost Per Unit  Total Cost  \
# 0        Alone Sanitizers  MedSupplies       144         487.83    70247.52
# 1   Foot Diagnostic Tools     CareWell       152         334.54    50850.08
# 2    Air Diagnostic Tools     CareWell       258         481.12   124128.96
# 3  Child Diagnostic Tools     MediCorp       234         405.56    94901.04
# 4        Exactly Medicine     MediCorp        57         284.75    16230.75
#
#   Expiry Date   Storage Location  Stock Status  Order Date Delivery Date
# 0  2026-12-03      Main Hospital     Low Stock  2022-12-05    2024-12-29
# 1  2027-05-01      Clinic Branch     Available  2023-03-16    2023-04-13
# 2  2026-12-29  Emergency Storage  Out of Stock  2024-08-13           NaN
# 3  2025-10-11        Warehouse B     Low Stock  2022-09-14    2025-02-25
# 4  2027-04-17      Main Hospital     Available  2022-10-14    2024-01-06

# %%
df.info
# Out:
# <bound method DataFrame.info of                                      Item Name     Supplier  Quantity  \
# 0                             Alone Sanitizers  MedSupplies       144
# 1                        Foot Diagnostic Tools     CareWell       152
# 2                         Air Diagnostic Tools     CareWell       258
# 3                       Child Diagnostic Tools     MediCorp       234
# 4                             Exactly Medicine     MediCorp        57
# ...                                        ...          ...       ...
# 7995                           Hour Sanitizers  HealthFirst        98
# 7996  Experience Personal Protective Equipment     MediCorp       243
# 7997                   Play Surgical Equipment  HealthFirst       124
# 7998     Purpose Personal Protective Equipment   PharmaPlus       278
# 7999                     Term Diagnostic Tools     MediCorp        59
#
#       Cost Per Unit  Total Cost Expiry Date   Storage Location  Stock Status  \
# 0            487.83    70247.52  2026-12-03      Main Hospital     Low Stock
# 1            334.54    50850.08  2027-05-01      Clinic Branch     Available
# 2            481.12   124128.96  2026-12-29  Emergency Storage  Out of Stock
# 3            405.56    94901.04  2025-10-11        Warehouse B     Low Stock
# 4            284.75    16230.75  2027-04-17      Main Hospital     Available
# ...             ...         ...         ...                ...           ...
# 7995         468.62    45924.76  2028-02-18      Main Hospital     Available
# 7996         163.00    39609.00  2026-08-14      Main Hospital     Low Stock
# 7997         283.10    35104.40  2026-08-15      Clinic Branch     Available
# 7998         335.53    93277.34  2024-11-18        Warehouse A  Out of Stock
# 7999         263.64    15554.76  2027-11-02      Clinic Branch     Low Stock
#
#       Order Date Delivery Date
# 0     2022-12-05    2024-12-29
# 1     2023-03-16    2023-04-13
# 2     2024-08-13           NaN
# 3     2022-09-14    2025-02-25
# 4     2022-10-14    2024-01-06
# ...          ...           ...
# 7995  2022-06-03    2024-05-14
# 7996  2023-01-20    2023-07-31
# 7997  2024-03-19    2024-08-25
# 7998  2024-12-09    2025-03-08
# 7999  2022-11-07    2023-11-05
#
# [8000 rows x 10 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                      Item Name     Supplier  Quantity  \
# 0                             Alone Sanitizers  MedSupplies       144
# 1                        Foot Diagnostic Tools     CareWell       152
# 2                         Air Diagnostic Tools     CareWell       258
# 3                       Child Diagnostic Tools     MediCorp       234
# 4                             Exactly Medicine     MediCorp        57
# ...                                        ...          ...       ...
# 7995                           Hour Sanitizers  HealthFirst        98
# 7996  Experience Personal Protective Equipment     MediCorp       243
# 7997                   Play Surgical Equipment  HealthFirst       124
# 7998     Purpose Personal Protective Equipment   PharmaPlus       278
# 7999                     Term Diagnostic Tools     MediCorp        59
#
#       Cost Per Unit  Total Cost Expiry Date   Storage Location  Stock Status  \
# 0            487.83    70247.52  2026-12-03      Main Hospital     Low Stock
# 1            334.54    50850.08  2027-05-01      Clinic Branch     Available
# 2            481.12   124128.96  2026-12-29  Emergency Storage  Out of Stock
# 3            405.56    94901.04  2025-10-11        Warehouse B     Low Stock
# 4            284.75    16230.75  2027-04-17      Main Hospital     Available
# ...             ...         ...         ...                ...           ...
# 7995         468.62    45924.76  2028-02-18      Main Hospital     Available
# 7996         163.00    39609.00  2026-08-14      Main Hospital     Low Stock
# 7997         283.10    35104.40  2026-08-15      Clinic Branch     Available
# 7998         335.53    93277.34  2024-11-18        Warehouse A  Out of Stock
# 7999         263.64    15554.76  2027-11-02      Clinic Branch     Low Stock
#
#       Order Date Delivery Date
# 0     2022-12-05    2024-12-29
# 1     2023-03-16    2023-04-13
# 2     2024-08-13           NaN
# 3     2022-09-14    2025-02-25
# 4     2022-10-14    2024-01-06
# ...          ...           ...
# 7995  2022-06-03    2024-05-14
# 7996  2023-01-20    2023-07-31
# 7997  2024-03-19    2024-08-25
# 7998  2024-12-09    2025-03-08
# 7999  2022-11-07    2023-11-05
#
# [8000 rows x 10 columns]>

# %%
print(df.isnull().sum())
# Out:
# Item Name             0
# Supplier            178
# Quantity              0
# Cost Per Unit         0
# Total Cost            0
# Expiry Date           0
# Storage Location      0
# Stock Status          0
# Order Date            0
# Delivery Date       834
# dtype: int64

# %%
df.shape
# Out:
# (8000, 10)

# %%
df.dropna
df.shape
# Out:
# (8000, 10)

# %%
# Fill missing supplier names with 'Unknown'
df['Supplier'].fillna('Unknown', inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Item Name             0
# Supplier              0
# Quantity              0
# Cost Per Unit         0
# Total Cost            0
# Expiry Date           0
# Storage Location      0
# Stock Status          0
# Order Date            0
# Delivery Date       834
# dtype: int64

# %%
# Fill missing 'Delivery Date' with 'Not Delivered'
df["Delivery Date"].fillna("Not Delivered", inplace=True)

# %%
# If 'Total Cost' is NaN, recalculate it (Quantity * Cost Per Unit)
df["Total Cost"] = df["Quantity"] * df["Cost Per Unit"]

# %%
# Convert 'Expiry Date' column to datetime, replace invalid values with a future date
def fix_expiry_date(date):
    try:
        return pd.to_datetime(date)  # Convert valid dates
    except:
        return pd.to_datetime("2099-12-31")  # Replace invalid dates with a far future date

df["Expiry Date"] = df["Expiry Date"].apply(fix_expiry_date)

# %%
# Drop duplicate rows
df.drop_duplicates(inplace=True)

# %%
# Reset index and rename
df.reset_index(inplace=True)
df.rename(columns={"index": "id",
                   "Storage Location": "Location"}, inplace=True)

# %%
# Convert 'Item Name', 'Supplier', and 'Storage Location' to Title Case
df["Item Name"] = df["Item Name"].str.title()
df["Supplier"] = df["Supplier"].str.title()
df["Location"] = df["Location"].str.title()
df["Stock Status"] = df["Stock Status"].str.title()

# %%
df["Cost Per Unit"] = df["Cost Per Unit"].replace(r"[₹,]", "", regex=True).astype(float)
df["Total Cost"] = df["Total Cost"].replace(r"[₹,]", "", regex=True).astype(float)

# Round 'Cost Per Unit' and 'Total Cost' to 2 decimal places
df["Cost Per Unit"] = df["Cost Per Unit"].round(2)
df["Total Cost"] = df["Total Cost"].round(2)

# %%
# Fill missing Expiry Date and Order Date with a placeholder or forward fill
df["Expiry Date"].fillna("Not Available", inplace=True)
df["Order Date"].fillna("Not Available", inplace=True)

# %%
# Convert Order & delivery Date to datetime format
df["Order Date"] = pd.to_datetime(df["Order Date"], errors="coerce")
df["Delivery Date"] = pd.to_datetime(df["Delivery Date"], errors="coerce").dt.date
df["Delivery Date"] = df["Delivery Date"].fillna("Not Delivered")

# %%
#add column for delivery status
df["delivery_status"] = df["Delivery Date"].apply(lambda x: "Pending" if x == "Not Delivered" else "Delivered")
df["delivery_status"] = df["delivery_status"].astype("category")

# %%
print(df.dtypes)
# Out:
# id                          int64
# Item Name                  object
# Supplier                   object
# Quantity                    int64
# Cost Per Unit             float64
# Total Cost                float64
# Expiry Date        datetime64[ns]
# Location                   object
# Stock Status               object
# Order Date         datetime64[ns]
# Delivery Date              object
# delivery_status          category
# dtype: object

# %%
df["days_to_expiry"] = (df["Expiry Date"] - pd.Timestamp.today()).dt.days
df["expiry_status"] = df["days_to_expiry"].apply(lambda x: "Expired" if x < 0 else "Valid")

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
df.sample(10)
# Out:
#         id                             item_name     supplier  quantity  \
# 777    777            Necessary Diagnostic Tools     Carewell        63
# 2674  2674  Health Personal Protective Equipment   Pharmaplus        47
# 5942  5942                But Surgical Equipment  Healthfirst         0
# 5920  5920                           As Medicine  Healthfirst        32
# 5910  5910             Reason Surgical Equipment  Healthfirst       216
# 3805  3805                     Yourself Medicine      Unknown       282
# 1493  1493                        Sea Sanitizers     Medicorp         4
# 1550  1550              Staff Surgical Equipment  Medsupplies       248
# 37      37                    Political Medicine     Carewell       265
# 3980  3980            Reflect Surgical Equipment     Medicorp       110
#
#       cost_per_unit  total_cost expiry_date           location  stock_status  \
# 777          430.83    27142.29  2027-06-11        Warehouse B     Available
# 2674         251.91    11839.77  2028-02-16      Main Hospital     Available
# 5942         126.73        0.00  2027-01-21      Main Hospital  Out Of Stock
# 5920         410.58    13138.56  2024-09-15      Main Hospital     Available
# 5910         456.75    98658.00  2025-03-28  Emergency Storage     Low Stock
# 3805         371.20   104678.40  2024-10-28  Emergency Storage     Low Stock
# 1493         287.33     1149.32  2024-03-07        Warehouse B     Available
# 1550          80.33    19921.84  2027-12-26        Warehouse A  Out Of Stock
# 37           404.87   107290.55  2024-11-10  Emergency Storage  Out Of Stock
# 3980          13.15     1446.50  2027-10-15  Emergency Storage     Available
#
#      order_date  delivery_date delivery_status  days_to_expiry expiry_status
# 777  2024-04-08     2024-04-18       Delivered             834         Valid
# 2674 2022-12-19     2023-11-03       Delivered            1084         Valid
# 5942 2023-07-28     2024-12-11       Delivered             693         Valid
# 5920 2024-01-07     2024-03-20       Delivered            -165       Expired
# 5910 2024-10-10     2025-02-12       Delivered              29         Valid
# 3805 2022-06-12     2024-05-23       Delivered            -122       Expired
# 1493 2023-02-09     2025-03-06       Delivered            -357       Expired
# 1550 2024-03-22     2024-09-02       Delivered            1032         Valid
# 37   2023-12-05  Not Delivered         Pending            -109       Expired
# 3980 2024-09-26     2025-02-01       Delivered             960         Valid

# %%
print(df.isnull().sum())
# Out:
# id                 0
# item_name          0
# supplier           0
# quantity           0
# cost_per_unit      0
# total_cost         0
# expiry_date        0
# location           0
# stock_status       0
# order_date         0
# delivery_date      0
# delivery_status    0
# days_to_expiry     0
# expiry_status      0
# dtype: int64

# %%
df.to_csv("cleaned.csv")

# %%
# !pip install pyodbc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyodbc in c:\programdata\anaconda3\lib\site-packages (5.1.0)

# %%
import pyodbc

cnxn = pyodbc.connect(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=SHARVANIMAHADIK\\SQLEXPRESS;"
    "Database=hospital;"
    "Trusted_Connection=yes;"
)
